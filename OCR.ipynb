# %%
import cv2
import numpy as np
from PIL import Image
import PIL.Image
# !pip install pytesseract
from pytesseract import image_to_string
import pytesseract
# Out:
# Collecting pytesseract
#   Downloading pytesseract-0.3.7.tar.gz (13 kB)
# Requirement already satisfied: Pillow in c:\users\bhavs\appdata\local\programs\python\python38\lib\site-packages (from pytesseract) (8.1.2)
# Using legacy 'setup.py install' for pytesseract, since package 'wheel' is not installed.
# Installing collected packages: pytesseract
#     Running setup.py install for pytesseract: started
#     Running setup.py install for pytesseract: finished with status 'done'
# Successfully installed pytesseract-0.3.7

# %%
pytesseract.pytesseract.tesseract_cmd = 'C:/Program Files/Tesseract-OCR/tesseract'
TESSDATA_PREFIX = 'C:/Program Files /Tesseract-OCR'
output = pytesseract.image_to_string(PIL.Image.open('image.jpg').convert("RGB"), lang='eng')
print(output)
# Out:
# Why Buy
# Custom Face Masks?
#
#
#
# — The Impact of Custom Face Masks =
#
# hs
# of consumers wear all
# or most of the time when in public
#
# io
#
# Pte
#
#
#
# would keep a logoed
# mask more than
#
# = 11%
#
# would use their logoed mask
# on a weekly basis or more often
#
# 57%
#
# of consumers would be more likely
# to do business with the advertiser
# who gave them a promo mask
#
# 4,235
#
# Number of impressions per promo
# mask over its anticipated lifetime
#
#
#
#
#
#
# that costs
# will have a CPI (cost per
# impression) of just over
#
#
#
# Why Buy Custom Face Masks?
#
# Even though budgets can be challenging during the
# pandemic, custom face masks are still a great investment.
# Here's why:
#
# Custom masks give you a chance to show you care
#
# Actions speak louder than words. Not many
# inexpensive promotional gifts can save lives.
# Masks represent a rare opportunity to show
# clients, customers, employees, students,
# parents and the public that you have their
# best interests at heart.
#
# Masks with a logo encourage solidarity
#
# Schools, companies, nonprofits and
# more will feel united when they are all
# sporting the same logo, in support of
# each other’s health and safety.
#
# Mask giveaways encourage and increase mask wearing
#
# If you need your staff, customers,
# event participants or students to
# wear a mask, and regulate the
# quality and efficacy of the mask
# used, it really helps if you
# provide one.
#
#
#
# Promotional face masks provide instant brand amplification
# Everyone needs face masks to go out in public, and most
# people keep multiples handy: one for the office, one for the
# car, two in a purse, two by the door, and so on. If you give
# out a free face mask, it will not only be worn, but it will
# meet up with several new potential customers or recruits
# everywhere it is seen.
#
# *Statistics provided by ASI Advertising Specialty Institute
#
#
#
# Customize your own face masks today at Crestline.com!
#
# @S CRESTLINE’
#
# Ww WE KNOW PROMO™

# %%
from skimage.io import imshow

# %%
pytesseract.pytesseract.tesseract_cmd = 'C:/Program Files/Tesseract-OCR/tesseract'
TESSDATA_PREFIX = 'C:/Program Files /Tesseract-OCR'
output = pytesseract.image_to_string(PIL.Image.open('image.jpg').convert("RGB"), lang='eng')
print(output)
# Out:
# Why Buy
# Custom Face Masks?
#
#
#
# — The Impact of Custom Face Masks =
#
# hs
# of consumers wear all
# or most of the time when in public
#
# io
#
# Pte
#
#
#
# would keep a logoed
# mask more than
#
# = 11%
#
# would use their logoed mask
# on a weekly basis or more often
#
# 57%
#
# of consumers would be more likely
# to do business with the advertiser
# who gave them a promo mask
#
# 4,235
#
# Number of impressions per promo
# mask over its anticipated lifetime
#
#
#
#
#
#
# that costs
# will have a CPI (cost per
# impression) of just over
#
#
#
# Why Buy Custom Face Masks?
#
# Even though budgets can be challenging during the
# pandemic, custom face masks are still a great investment.
# Here's why:
#
# Custom masks give you a chance to show you care
#
# Actions speak louder than words. Not many
# inexpensive promotional gifts can save lives.
# Masks represent a rare opportunity to show
# clients, customers, employees, students,
# parents and the public that you have their
# best interests at heart.
#
# Masks with a logo encourage solidarity
#
# Schools, companies, nonprofits and
# more will feel united when they are all
# sporting the same logo, in support of
# each other’s health and safety.
#
# Mask giveaways encourage and increase mask wearing
#
# If you need your staff, customers,
# event participants or students to
# wear a mask, and regulate the
# quality and efficacy of the mask
# used, it really helps if you
# provide one.
#
#
#
# Promotional face masks provide instant brand amplification
# Everyone needs face masks to go out in public, and most
# people keep multiples handy: one for the office, one for the
# car, two in a purse, two by the door, and so on. If you give
# out a free face mask, it will not only be worn, but it will
# meet up with several new potential customers or recruits
# everywhere it is seen.
#
# *Statistics provided by ASI Advertising Specialty Institute
#
#
#
# Customize your own face masks today at Crestline.com!
#
# @S CRESTLINE’
#
# Ww WE KNOW PROMO™
